# %% [markdown]
# # Conceptos Basicos Notebooks

# %% [markdown]
# ## Codigo, Markdown y Celda

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## Imprimir Codigo

# %%
x = "Hola Mundo"

# %%
print(x)
# Out:
# Hola Mundo

# %% [markdown]
# ## Tablas

# %%
import pandas as pd

tabla=pd.DataFrame(data = [[1,1], [2,4], [3,9]],
                   columns = ['numero', 'cuadrado']
                  )

tabla
# Out:
#    numero  cuadrado
# 0       1         1
# 1       2         4
# 2       3         9

# %% [markdown]
# ## Graficas

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Imagen

# %% [markdown]
# ![anaconda-python.png](attachment:20c45cc2-e0ba-400b-947d-d7e3bc962d54.png)

# %% [markdown]
# ## Conclusiones
# * Primero
# * Segundo
# * Tercero

# %% [markdown]
# # NuncaParesDeAprender!
